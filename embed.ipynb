# %%
import random
import pandas as pd 

from langchain_community.vectorstores import Qdrant
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_ollama import ChatOllama
from langchain.chat_models import init_chat_model
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain import hub
from typing_extensions import List, TypedDict, Optional
from langgraph.graph import START, StateGraph
from langchain_core.documents import Document

# %%
with open('fireworksai_api_key.txt', 'r') as file:
    API_KEY = file.read().strip()

# %%
FEET_TO_CM = 30.48

# %%
data = pd.read_csv('data/texas_plant_list.csv')

# %%
data['Price'] = None
data['Delivery'] = None
data['Labels'] = None

for i in range(len(data)):
    data.at[i, 'Price'] = round(random.uniform(1, 100)) + random.choice([0, 0.50, 0.99])
    data.at[i, 'Delivery'] = random.choice(['Delivered within 2 weeks', 'Delivered within 1 week', 'Buy today, delivered tomorrow'])
    data.at[i, 'Labels'] = random.choice(['ONLY ONLINE', 'BULK DISCOUNT', 'PROMOTION', 'NEW', 'SOLD OUT'])

# %%
data['Growth Form'] = data['Growth Form'].apply(lambda x: ', '.join(eval(x)) if isinstance(x, str) else x)
data['Native Habitat'] = data['Native Habitat'].apply(lambda x: ', '.join(eval(x)) if isinstance(x, str) else x)

data['Min Height'] = data['Min Height'] * FEET_TO_CM
data['Max Height'] = data['Max Height'] * FEET_TO_CM
data['Min Spread'] = data['Min Spread'] * FEET_TO_CM
data['Max Spread'] = data['Max Spread'] * FEET_TO_CM

data = data.drop_duplicates(subset='Scientific Name', keep='first')
data.reset_index(drop=True, inplace=True)

data = data.fillna('Unknown')
# Out:
# /var/folders/22/ylp5_m552sncv029350y01gw0000gn/T/ipykernel_60458/3302540911.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data = data.fillna('Unknown')

# %%
# data.to_csv('data/texas_plant_list_cleaned.csv', index=False)

# %%
docs = []

count = 1

for i in range(len(data)):
  t = (
      f"ID: {count} | "
      f"Latin Name: {data.at[i, 'Scientific Name']} | "
      f"Common Name: {data.at[i, 'Common Name']} | "

      # f"Ecoregion: {data.at[i, 'Ecoregion III']} | "
      f"Native Habitat: {data.at[i, 'Native Habitat']} | "

      f"Growth Form: {data.at[i, 'Growth Form']} | "

      f"Bloom Season: {data.at[i, 'Bloom Season']} | "
      f"Bloom Color: {data.at[i, 'Bloom Color']} | "

      # f"Leaf Retention: {data.at[i, 'Leaf Retention']} | "
      f"Lifespan: {data.at[i, 'Lifespan']} | "

      f"Wildlife Benefit: {data.at[i, 'Wildlife Benefit']} | "

      f"Soil: {data.at[i, 'Soil']} | "
      f"Light: {data.at[i, 'Light']} | "
      f"Water: {data.at[i, 'Water']} | "
      
      f"Min Height (cm): {data.at[i, 'Min Height']} | "
      f"Max Height (cm): {data.at[i, 'Max Height']} | "
      f"Min Spread (cm): {data.at[i, 'Min Spread']} | "
      f"Max Spread (cm): {data.at[i, 'Max Spread']} | "

      f"Maintenence: {data.at[i, 'Maintenence']} | "
      f"Comments: {data.at[i, 'Comments']}"

      # f"Price (euro): {data.at[i, 'Price']} | "
      # f"Delivery: {data.at[i, 'Delivery']} | "
      # f"Labels: {data.at[i, 'Labels']}"
  )
  
  docs.append(t)

  count += 1

print(docs[5])
print(docs[5].__len__())
# Out:
# ID: 6 | Latin Name: Acer rubrum var. drummondii | Common Name: Drummond Red Maple | Native Habitat: Woodland, Wetland or Riparian | Growth Form: Tree | Bloom Season: Spring | Bloom Color: Red | Lifespan: Perennial | Wildlife Benefit: Beetles, Butterflies, Birds, Small Mammals, Deer, Moths, Bees | Soil: Sand, Loam, Clay, Calcareous, Poor Drainage, Moist | Light: Sun, Part Shade | Water: Medium, High | Min Height (cm): 1524.0 | Max Height (cm): 2743.2 | Min Spread (cm): 914.4 | Max Spread (cm): 1828.8 | Maintenence: Fast growth rate. Tolerates a wide range of soil conditions. A showy shade tree with attractive fall foliage. The fallen leaves decompose over time, releasing essential nutrients back into the soil. This process enriches the surrounding environment, supporting the growth of other plant species and wildlife. Prefers moist, swampy sites and is not as cold hardy as other maples. Propagation: seed. | Comments: Blooms February-April. Forms a dense crown with sturdy branches. Leaves are 3- to 5-lobed, but are different from the other Maples by being hairy on the silvery lower surface of its leaves. Male and female flowers are found on separate trees. In spring the tree is covered with decorative red male flowers. Female trees produce seeds called samaras. The tree's bark provides a habitat for a variety of organisms: beetles and spiders find refuge, creating a miniature ecosystem within the tree itself. Larval host: Sphinx Moths. Although still listed by some in the Aceraceae Family, the majority of botanical organizations now list it in the Sapindaceae Family.
#
#
# 1595

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2"
)

# qdrant = Qdrant.from_texts(
#     docs,
#     embeddings,
#     path="vector_stores/plantkiezer1", 
#     collection_name="planten",
# )

# %% [markdown]
# ______

# %%
vectorstore = Qdrant.from_existing_collection(
    collection_name="planten",
    embedding=embeddings,
    path="vector_stores/plantkiezer1",
)

# %%
query = "Which plants are nice in a humid environment?"

# %% [markdown]
# # Query Expansion

# %%
instruction = "You enrich a user query for dense vector search. Return ONE line: the original query first, then up to 5 short synonym/keyword variants separated by ' | '. Preserve intent; prefer domain-specific terms likely found in the corpus. Each variant 2-6 words. No quotes, no explanations, no boolean operators, nothing else."

# %%
llm = ChatOllama(
    model="gemma3:4b", 
    keep_alive="30m",
    num_ctx=2048,
    num_predict=256,
    temperature=0.5
)

# %%
messages = [
    (
        "system",
        instruction,
    ),
    (
        "human", 
        query),
]

# %%
query_updated = llm.invoke(messages).content

# %% [markdown]
# # Retrieve and Chat Test

# %%
unique_documents = list(doc.page_content for doc in vectorstore.max_marginal_relevance_search(query_updated, k=5, filter=None))

# %%
llm = init_chat_model(
    "accounts/fireworks/models/deepseek-v3",
    # "accounts/fireworks/models/qwen3-30b-a3b-instruct-2507", 
    # "accounts/fireworks/models/gpt-oss-20b",
    # "accounts/fireworks/models/gpt-oss-120b",
    model_provider="fireworks", 
    api_key=API_KEY
)

# MODEL = "gpt-oss-20b"
# MODEL = "gpt-oss-120b"
# MODEL = "qwen3-30b"
MODEL = "deepseek-v3"

# %%
prompt = hub.pull("rlm/rag-prompt")

class State(TypedDict):
    question: str
    context: List[Document]
    answer: str
    
    # generation & retrieval controls
    max_tokens: Optional[int]
    top_p: Optional[float]
    top_k: Optional[int]
    presence_penalty: Optional[float]
    frequency_penalty: Optional[float]
    temperature: Optional[float]

def retrieve(state: State):
    retrieved_docs = vectorstore.max_marginal_relevance_search(query_updated, k=5, filter=None)
    
    return {"context": retrieved_docs}

def generate(state: State):
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    messages = prompt.invoke({"question": state["question"], "context": docs_content})
    response = llm.invoke(messages)

    return {"answer": response.content}

graph_builder = StateGraph(State).add_sequence([retrieve, generate])
graph_builder.add_edge(START, "retrieve")
graph = graph_builder.compile()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/langsmith/client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
instruction = "You are an expert botanical assistant. You will be provided with five retrieved plant entries. Choose three of them that you think answers the user query the best and recommend it. Use the descriptions of the retrieved data to also provide more information about the plants."

# %%
response = graph.invoke({
        "question": query,
        "max_tokens": 1024,
        "top_p": 1,
        "top_k": 40,
        "presence_penalty": 0,
        "frequency_penalty": 0,
        "temperature": 0.6,
    })

# %%
response['answer']
# Out:
# 'The **Louisiana Spiderlily (Hymenocallis liriosme)** is well-suited for humid environments, as it thrives in moist to wet soils and part shade. Its perennial nature and fragrant white blooms make it an excellent choice for humid, wetland areas.'

# %%
data
# Out:
#              Scientific Name           Common Name  \
# 0            Abronia ameliae       Heart's Delight
# 1        Acacia angustissima        Prairie Acacia
# 2            Acer floridanum  Southern Sugar Maple
# 3        Acer grandidentatum        Bigtooth Maple
# 4               Acer negundo             Box Elder
# ..                       ...                   ...
# 690  Zephyranthes drummondii          Prairie Lily
# 691           Zinnia acerosa         Desert Zinnia
# 692       Zinnia grandiflora         Plains Zinnia
# 693              Zizia aurea     Golden Alexanders
# 694     Ziziphus obtusifolia              Lotebush
#
#                                     Other Common Names  \
# 0                                Amelia's Sand-verbena
# 1    White Ball Acacia, Fern Acacia, Whiteball Acac...
# 2               Caddo Maple, Florida Maple, Rock Maple
# 3    Big-toothed Maple, Uvalde Bigtooth Maple, Sout...
# 4                                              Unknown
# ..                                                 ...
# 690  Hill Country Rain Lily, Rain Lily, Flor De May...
# 691  Dwarf Zinnia, Dwarf White Zinnia, Shrubby Zinn...
# 692  Rocky Mountain Zinnia, Prairie Zinnia, Little ...
# 693                                       Golden Zizia
# 694                               Graythorn, Lote Bush
#
#                  Growth Form  \
# 0                 Herbaceous
# 1          Herbaceous, Shrub
# 2                       Tree
# 3                       Tree
# 4                       Tree
# ..                       ...
# 690               Herbaceous
# 691  Groundcover, Herbaceous
# 692                    Shrub
# 693               Herbaceous
# 694                     Tree
#
#                                          Ecoregion III  \
# 0    Gulf Coast Prairies and Marshes, Southern Texa...
# 1    Central Great Plains, Chihuahuan Deserts, Cros...
# 2                           Western Gulf Coastal Plain
# 3    Chihuahuan Deserts, Cross Timbers, Edwards Pla...
# 4    Cross Timbers, East Central Texas Plains, Edwa...
# ..                                                 ...
# 690  East Central Texas Plains, Edwards Plateau, Gu...
# 691                                 Chihuahuan Deserts
# 692  Chihuahuan Deserts, Edwards Plateau, High Plai...
# 693  East Central Texas Plains, Western Gulf Coasta...
# 694  Central Great Plains, Chihuahuan Deserts, Cros...
#
#                                           Ecoregion IV Min Height Max Height  \
# 0    , , , , , Coastal Sand Plain, , Rio Grande Flo...      30.48      45.72
# 1    Broken Red Plains,Limestone Plains,Red Prairie...      30.48      91.44
# 2    , , , , , , , , , , Flatwoods,Floodplains and ...      609.6     3048.0
# 3    , Chihuahuan Desert Grasslands,Chihuahuan Mont...      457.2     1219.2
# 4    , , Eastern Cross Timbers,Grand Prairie, Bastr...     1066.8     1828.8
# ..                                                 ...        ...        ...
# 690  , , , Southern Post Oak Savanna, Balcones Cany...      15.24      30.48
# 691  , Chihuahuan Basins and Playas,Chihuahuan Dese...      15.24      30.48
# 692  , Chihuahuan Basins and Playas,Chihuahuan Dese...      15.24      22.86
# 693  , , , Northern Post Oak Savanna,Northern Prair...      30.48      91.44
# 694  Broken Red Plains,Limestone Plains,Red Prairie...     274.32     396.24
#
#     Min Spread Max Spread  ...          Bloom Season           Bloom Color  \
# 0        15.24      30.48  ...                Spring          Pink, Purple
# 1        45.72      60.96  ...          Summer, Fall                 White
# 2       365.76     1828.8  ...                Spring         Yellow, Green
# 3        304.8      457.2  ...                Spring         Yellow, Green
# 4        914.4     1524.0  ...                Spring  Yellow, Green, Brown
# ..         ...        ...  ...                   ...                   ...
# 690      3.048       7.62  ...        Spring, Summer           White, Pink
# 691      30.48      45.72  ...                Summer         White, Yellow
# 692      15.24      30.48  ...  Spring, Summer, Fall                Yellow
# 693      30.48      60.96  ...        Spring, Summer                Yellow
# 694     182.88     243.84  ...                Spring         Yellow, Green
#
#                                      Seasonal Interest  \
# 0                                       Nectar, Pollen
# 1                           Seeds, Nectar, Larval Host
# 2                                    Fall Color, Seeds
# 3    Fall Color, Seeds, Forage, Nectar, Pollen, Flo...
# 4       Fall Color, Seeds, Nectar, Pollen, Larval Host
# ..                                                 ...
# 690                                     Nectar, Pollen
# 691                                     Nectar, Pollen
# 692                                     Nectar, Pollen
# 693                        Nectar, Pollen, Larval Host
# 694            Fruit, Forage, Nectar, Nesting Material
#
#                                       Wildlife Benefit  \
# 0                   Butterflies, Nectar Insects, Moths
# 1    Butterflies, Birds, Small Mammals, Nectar Inse...
# 2                                 Birds, Small Mammals
# 3          Browsers, Butterflies, Birds, Small Mammals
# 4                                   Birds, Moths, Bees
# ..                                                 ...
# 690                                  Butterflies, Bees
# 691                                  Butterflies, Bees
# 692                           Butterflies, Moths, Bees
# 693  Caterpillars, Butterflies, Nectar Insects, Mot...
# 694     Browsers, Birds, Small Mammals, Nectar Insects
#
#                                            Maintenence  \
# 0    A short-lived perennial. Abronias do not trans...
# 1    Drought Tolerant. Colonizes by rhizomes, and i...
# 2    Moderate to fast growth rate. This small, spre...
# 3    Slow growth rate, especially in the first few ...
# 4    Low maintenance, adaptable. Fast growth rate. ...
# ..                                                 ...
# 690  Very low maintenance. Tends to have a main spr...
# 691  Low maintenance. Makes a good groundcover. Wor...
# 692  Prefers dry, gravelly rock gardens, and well-d...
# 693  A short-lived perennial that also spreads easi...
# 694  Low maintenance. Tolerates a range of soils.  ...
#
#                                               Comments  \
# 0    Blooms January-June. Stems are coarse and hair...
# 1    Blooms June-September. A mounding, thornless a...
# 2    A smaller southern version of the Sugar Maple....
# 3    Blooms March-April. The western relative of Su...
# 4    Usually a small to medium-sized tree. It doesn...
# ..                                                 ...
# 690  Blooms March-August. Bulbs produce blue-green ...
# 691  Blooms June-August. A low, mounding plant with...
# 692  Blooms April-November. A mound-shaped plant wi...
# 693  Blooms April-August. Erect, branching, form wi...
# 694  Blooms March-April. Densely branched shrub wit...
#
#                                             References  Price  \
# 0    1) Griffith, Bryce, Omernick & Rodgers (2007)....  64.50
# 1    1) Griffith, Bryce, Omernick & Rodgers (2007)....  62.00
# 2    1) Griffith, Bryce, Omernick & Rodgers (2007)....  82.99
# 3    1) Griffith, Bryce, Omernick & Rodgers (2007)....  14.00
# 4    1) Griffith, Bryce, Omernick & Rodgers (2007)....  41.99
# ..                                                 ...    ...
# 690  1) https://www.itis.gov/servlet/SingleRpt/Sing...  96.00
# 691  1) http://bonap.net/TDC/Image/Map?taxonType=Sp...  89.50
# 692  1)  Griffith, Bryce, Omernick & Rodgers (2007)...  31.50
# 693  1) https://portal.torcherbaria.org/portal/taxa...  74.50
# 694  1) https://southwestdesertflora.com/WebsiteFol...  64.99
#
#                           Delivery         Labels
# 0    Buy today, delivered tomorrow      PROMOTION
# 1         Delivered within 2 weeks       SOLD OUT
# 2    Buy today, delivered tomorrow       SOLD OUT
# 3          Delivered within 1 week  BULK DISCOUNT
# 4          Delivered within 1 week    ONLY ONLINE
# ..                             ...            ...
# 690  Buy today, delivered tomorrow      PROMOTION
# 691       Delivered within 2 weeks       SOLD OUT
# 692       Delivered within 2 weeks  BULK DISCOUNT
# 693        Delivered within 1 week       SOLD OUT
# 694        Delivered within 1 week       SOLD OUT
#
# [695 rows x 26 columns]
